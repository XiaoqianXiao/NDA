# %%
import os
import glob
import pandas as pd
import openpyxl

# %%
NDA_dir = '/Users/xiaoqianxiao/lab/R01/NDA'
version = 'sumission_20260715'
meta_file_name = 'IFOCUSS_SubInfo.csv'
sumission_dir = os.path.join(NDA_dir, version)
result_dir = os.path.join(sumission_dir, 'filled')
meta_file_path = os.path.join(sumission_dir, 'demo', meta_file_name)
df_meta = pd.read_csv(meta_file_path)
df_meta.head()
df_meta.columns
GUID_file_path = os.path.join(sumission_dir, 'demo', 'GUID_NoHIPinfo.csv')
df_GUID = pd.read_csv(GUID_file_path)
df_meta['ID'] = df_meta['ID'].astype(str).str.strip()
df_GUID['ID'] = df_GUID['ID'].astype(str).str.strip()
df_meta = df_meta.merge(df_GUID[['ID', 'GUID']], on='ID', how='left')
# Create date_of_birth column in yyyy/mm/dd format from MOB, DOB, YOB
df_meta['date_of_birth'] = df_meta.apply(
    lambda row: f"{int(row['YOB']):04d}/{int(row['MOB']):02d}/{int(row['DOB']):02d}" 
    if pd.notna(row['YOB']) and pd.notna(row['MOB']) and pd.notna(row['DOB']) 
    else None, axis=1
)

# %%
template_dir = '/Users/xiaoqianxiao/lab/R01/NDA/data_structure_templates'
defination_dir = '/Users/xiaoqianxiao/lab/R01/NDA/data_structure_defination'
approved_dir = os.path.join(template_dir, 'approved')
redcap_file_dir = os.path.join(sumission_dir,'CSV_from_Redcap')
match_file_path = os.path.join(template_dir, 'NDA_REDCap_matches.xlsx')
df_match_names = pd.ExcelFile(match_file_path)
list_questionnaire_names = df_match_names.sheet_names
print(f"Tabs found: {list_questionnaire_names}")
# Out:
# Tabs found: ['ndar_subject01', 'cde_gad701', 'cde_phq901', 'cde_dsm5crossad01', 'cde_whodas01', 'scidv_rv01', 'lsas01_sr', 'lsas01_cr', 'sds01', 'qids01', 'pswq01', 'hars01', 'babs01', 'rumination01']

# %%
#helper functions
# Calculate interview_age in months from date_of_birth to interview_date
# Age is rounded to chronological month: 15 days = 0 months, 16 days = 1 month
from datetime import datetime

# Calculate interview_age in months
def calculate_age_months(dob_str, interview_date_str):
    if pd.isna(dob_str) or pd.isna(interview_date_str):
        return None
    try:
        # Parse dates (date_of_birth is in yyyy/mm/dd format)
        dob = pd.to_datetime(dob_str, format='%Y/%m/%d')
        interview_date = pd.to_datetime(interview_date_str)
        
        # Calculate total days difference
        delta = interview_date - dob
        total_days = delta.days
        
        # Calculate base months (years * 12 + month difference)
        years = interview_date.year - dob.year
        months = interview_date.month - dob.month
        base_months = years * 12 + months
        
        # Adjust based on day of month
        # If interview day is earlier than birth day, we're in the previous month
        if interview_date.day < dob.day:
            base_months -= 1
            # Calculate days into the current month
            days_into_month = interview_date.day
        else:
            # Calculate days into the current month from birth day
            days_into_month = interview_date.day - dob.day
        
        # Apply rounding rule: 15 days = 0 months, 16 days = 1 month
        # If days_into_month >= 16, add 1 month
        if days_into_month >= 16:
            base_months += 1
        
        return max(0, base_months)  # Ensure non-negative
    except:
        return None

# Dictionary for phenotype_description mapping
dic_phenotype_description = {
    'HC': 'Matched healthy controls',
    'SAD': 'Patients with Anxiety Disorders',
    'BDD': 'Patients with Body Dysmorphic Disorder disorders',
    'SAD/BDD': 'Patients with Anxiety Disorders and Body Dysmorphic Disorder disorders'
}

# Dictionary for Race 1=American Indian/Alaska Native; 2=Asian; 3=Black or African American; 4=awaiian or Pacific Islander; 5=White; 6=More than one race; 7=Unknown or not reported
dic_race = {
    1: "American Indian/Alaska Native",
    2: "Asian",
    3: "Black or African American",
    4: "Hawaiian or Pacific Islander",
    5: "White",
    6: "More than one race",
    7: "Unknown or not reported"
}

dic_mdd_lp = {
    1:0,
    3:1
}

# %%
#1. ndar_subject01
#NDA: phenotype_description: HC=Matched healthy controls; SAD=Patients with anxiety disorders; BDD=Patients with Body Dysmorphic Disorder disorders
#interview_age: Age in months (Age is rounded to chronological month. If the research participant is 15-days-old at time of interview, the appropriate value would be 0 months. If the participant is 16-days-old, the value would be 1 month.)
#twins_study = 'NO'
#sibling_study = 'NO'
#family_study = 'NO'
#sample_taken = 'NO'
#M = Male; F = Female; O=Other; NR = Not reported
questionaire_name = 'ndar_subject01'
results_file = os.path.join(result_dir, f'{questionaire_name}.csv')
template_path = [f for f in glob.glob(os.path.join(approved_dir, '*.csv')) if questionaire_name.lower() in os.path.basename(f).lower()][0]
redcap_file_path = [f for f in glob.glob(os.path.join(redcap_file_dir, '*.csv')) if questionaire_name.lower() in os.path.basename(f).lower()][0]
df_template = pd.read_csv(template_path, header=1)
# Read the first row of template_path with all columns
first_row_template = pd.read_csv(template_path, header=None, nrows=1, names=df_template.columns)
df_redcap = pd.read_csv(redcap_file_path)
df_target_match_names = df_match_names.parse(questionaire_name, usecols=[0, 1])
valid_mappings = df_target_match_names.dropna(subset=['REDCap'])
df = df_template.copy() 
for index, row in valid_mappings.iterrows():
    nda_col = row['NDA_template']  # The destination column name
    redcap_col = row['REDCap']     # The source column name
    if redcap_col in df_redcap.columns:
        df[nda_col] = df_redcap[redcap_col]
# Merge GUID from df_meta to df['subjectkey'] based on matching ID
guid_map = df_meta.set_index('ID')['GUID'].to_dict()
df['src_subject_id'] = df['src_subject_id'].astype(str).str.strip()
df['subjectkey'] = df['src_subject_id'].map(guid_map)
# Merge SEX from df_meta to df['sex'] based on matching ID
sex_map = df_meta.set_index('ID')['SEX'].to_dict()
df['sex'] = df['src_subject_id'].map(sex_map)
df['sex'] = df['sex'].fillna('NR')
# Merge GROUP from df_meta to df['phenotype'] based on matching ID
dob_map = df_meta.set_index('ID')['GROUP'].to_dict()
df['phenotype'] = df['src_subject_id'].map(dob_map)
# Assign phenotype_description based on phenotype using dictionary
df['phenotype_description'] = df['phenotype'].map(dic_phenotype_description)
# Assign race based on race using dictionary
df['race'] = df['race'].map(dic_race)
# Set fixed values for study type fields
df['twins_study'] = 'No'
df['sibling_study'] = 'No'
df['family_study'] = 'No'
df['sample_taken'] = 'No'
# Merge date_of_birth from df_meta into df
dob_map = df_meta.set_index('ID')['date_of_birth'].to_dict()
df['date_of_birth'] = df['src_subject_id'].map(dob_map)
df['interview_age'] = df.apply(
    lambda row: calculate_age_months(row['date_of_birth'], row['interview_date']), 
    axis=1
)
# Convert interview_age to integer
df['interview_age'] = df['interview_age'].astype('Int64')
df = df.astype(object)
df = df.where(pd.notnull(df), None)
# Convert interview_date to 'MM/DD/YYYY' string format
df['interview_date'] = pd.to_datetime(df['interview_date'])
df['interview_date'] = df['interview_date'].dt.strftime('%m/%d/%Y')
# Trim df to only have columns as in df_template, in the exact same order
df = df[df_template.columns.tolist()]
# Add the first row from template_path to df
df = pd.concat([first_row_template, df], ignore_index=True)
df.iloc[0] = df.iloc[0].fillna('')
df.iloc[:1].to_csv(results_file, index=False, header=False, mode='w')
df.iloc[1:].to_csv(results_file, index=False, header=True, mode='a')

# %%
#2. cde_gad701
#NDA:  0 = Not at all; 1 = Several days; 2= More than half the days; 3 = Nearly every day; -9 = Missing.
#gad7_8: In what language did you collect the data? set to 1(English)
questionaire_name = 'cde_gad701'
results_file = os.path.join(result_dir, f'{questionaire_name}.csv')
template_path = [f for f in glob.glob(os.path.join(approved_dir, '*.csv')) if questionaire_name.lower() in os.path.basename(f).lower()][0]
redcap_file_path = [f for f in glob.glob(os.path.join(redcap_file_dir, '*.csv')) if questionaire_name.lower() in os.path.basename(f).lower()][0]
df_template = pd.read_csv(template_path, header=1)
# Read the first row of template_path with all columns
first_row_template = pd.read_csv(template_path, header=None, nrows=1, names=df_template.columns)
df_redcap = pd.read_csv(redcap_file_path)
df_target_match_names = df_match_names.parse(questionaire_name, usecols=[0, 1])
valid_mappings = df_target_match_names.dropna(subset=['REDCap'])
df = df_template.copy() 
for index, row in valid_mappings.iterrows():
    nda_col = row['NDA_template']  # The destination column name
    redcap_col = row['REDCap']     # The source column name
    if redcap_col in df_redcap.columns:
        df[nda_col] = df_redcap[redcap_col]
# Merge GUID from df_meta to df['subjectkey'] based on matching ID
guid_map = df_meta.set_index('ID')['GUID'].to_dict()
df['src_subject_id'] = df['src_subject_id'].astype(str).str.strip()
df['subjectkey'] = df['src_subject_id'].map(guid_map)
df = df.dropna(subset=['subjectkey'])
# Merge SEX from df_meta to df['sex'] based on matching ID
sex_map = df_meta.set_index('ID')['SEX'].to_dict()
df['sex'] = df['src_subject_id'].map(sex_map)
df['sex'] = df['sex'].fillna('NR')
# Merge date_of_birth from df_meta into df
dob_map = df_meta.set_index('ID')['date_of_birth'].to_dict()
df['date_of_birth'] = df['src_subject_id'].map(dob_map)
df['interview_age'] = df.apply(
    lambda row: calculate_age_months(row['date_of_birth'], row['interview_date']), 
    axis=1
)
df = df.dropna(subset=['interview_age'])
# Set gad7_8 to 1 as english
df['gad7_8'] = '1'
# Set GAD7's missing value to -9
gad7_cols = ['gad7_1', 'gad7_2', 'gad7_3', 'gad7_4', 'gad7_5', 'gad7_6', 'gad7_7']
df[gad7_cols] = df[gad7_cols].fillna(-9)
df[gad7_cols] = df[gad7_cols].astype('Int64')
# Convert interview_age to integer
df['interview_age'] = df['interview_age'].astype('Int64')
df = df.astype(object)
df = df.where(pd.notnull(df), None)
# Convert interview_date to 'MM/DD/YYYY' string format
df['interview_date'] = pd.to_datetime(df['interview_date'])
df['interview_date'] = df['interview_date'].dt.strftime('%m/%d/%Y')
# Trim df to only have columns as in df_template, in the exact same order
df = df[df_template.columns.tolist()]
# Add the first row from template_path to df
df = pd.concat([first_row_template, df], ignore_index=True)
df.iloc[0] = df.iloc[0].fillna('')
df.iloc[:1].to_csv(results_file, index=False, header=False, mode='w')
df.iloc[1:].to_csv(results_file, index=False, header=True, mode='a')

# %%
#3. cde_phq901
#NDA: 0 = Not at all; 1 = Several days; 2 = More than half the days; 3 = Nearly every day; -9 = Missing
#phq9_10: In what language did you collect the data? set to 1(English)
questionaire_name = 'cde_phq901'
results_file = os.path.join(result_dir, f'{questionaire_name}.csv')
template_path = [f for f in glob.glob(os.path.join(approved_dir, '*.csv')) if questionaire_name.lower() in os.path.basename(f).lower()][0]
redcap_file_path = [f for f in glob.glob(os.path.join(redcap_file_dir, '*.csv')) if questionaire_name.lower() in os.path.basename(f).lower()][0]
df_template = pd.read_csv(template_path, header=1)
# Read the first row of template_path with all columns
first_row_template = pd.read_csv(template_path, header=None, nrows=1, names=df_template.columns)
df_redcap = pd.read_csv(redcap_file_path)
df_target_match_names = df_match_names.parse(questionaire_name, usecols=[0, 1])
valid_mappings = df_target_match_names.dropna(subset=['REDCap'])
df = df_template.copy() 
for index, row in valid_mappings.iterrows():
    nda_col = row['NDA_template']  # The destination column name
    redcap_col = row['REDCap']     # The source column name
    if redcap_col in df_redcap.columns:
        df[nda_col] = df_redcap[redcap_col]
# Merge GUID from df_meta to df['subjectkey'] based on matching ID
guid_map = df_meta.set_index('ID')['GUID'].to_dict()
df['src_subject_id'] = df['src_subject_id'].astype(str).str.strip()
df['subjectkey'] = df['src_subject_id'].map(guid_map)
df = df.dropna(subset=['subjectkey'])
# Merge SEX from df_meta to df['sex'] based on matching ID
sex_map = df_meta.set_index('ID')['SEX'].to_dict()
df['sex'] = df['src_subject_id'].map(sex_map)
# Merge date_of_birth from df_meta into df
dob_map = df_meta.set_index('ID')['date_of_birth'].to_dict()
df['date_of_birth'] = df['src_subject_id'].map(dob_map)
df['interview_age'] = df.apply(
    lambda row: calculate_age_months(row['date_of_birth'], row['interview_date']), 
    axis=1
)
df = df.dropna(subset=['interview_age'])
# Set phq9_10 to 1 as english
df['phq9_10'] = '1'
# Set PHQ9's missing value to -9
phq9_cols = ['phq9_1', 'phq9_2', 'phq9_3', 'phq9_4', 'phq9_5', 'phq9_6', 'phq9_7', 'phq9_8', 'phq9_9']
df[phq9_cols] = df[phq9_cols].fillna(-9)
# Convert interview_age to integer
df['interview_age'] = df['interview_age'].astype('Int64')
df[phq9_cols] = df[phq9_cols].astype('Int64')
df = df.astype(object)
df = df.where(pd.notnull(df), None)
# Convert interview_date to 'MM/DD/YYYY' string format
df['interview_date'] = pd.to_datetime(df['interview_date'])
df['interview_date'] = df['interview_date'].dt.strftime('%m/%d/%Y')
# Trim df to only have columns as in df_template, in the exact same order
df = df[df_template.columns.tolist()]
# Add the first row from template_path to df
df = pd.concat([first_row_template, df], ignore_index=True)
df.iloc[0] = df.iloc[0].fillna('')
df.iloc[:1].to_csv(results_file, index=False, header=False, mode='w')
df.iloc[1:].to_csv(results_file, index=False, header=True, mode='a')

# %%
#4. cde_dsm5crossad01
#NDA: 0 = Not at all; 1 = Several days; 2 = More than half the days; 3 = Nearly every day; -9 = Missing
#dsm5crossad_24: In what language did you collect the data? set to 1(English)
questionaire_name = 'cde_dsm5crossad01'
results_file = os.path.join(result_dir, f'{questionaire_name}.csv')
template_path = [f for f in glob.glob(os.path.join(approved_dir, '*.csv')) if questionaire_name.lower() in os.path.basename(f).lower()][0]
redcap_file_path = [f for f in glob.glob(os.path.join(redcap_file_dir, '*.csv')) if questionaire_name.lower() in os.path.basename(f).lower()][0]
df_template = pd.read_csv(template_path, header=1)
# Read the first row of template_path with all columns
first_row_template = pd.read_csv(template_path, header=None, nrows=1, names=df_template.columns)
df_redcap = pd.read_csv(redcap_file_path)
df_target_match_names = df_match_names.parse(questionaire_name, usecols=[0, 1])
valid_mappings = df_target_match_names.dropna(subset=['REDCap'])
df = df_template.copy() 
for index, row in valid_mappings.iterrows():
    nda_col = row['NDA_template']  # The destination column name
    redcap_col = row['REDCap']     # The source column name
    if redcap_col in df_redcap.columns:
        df[nda_col] = df_redcap[redcap_col]
# Merge GUID from df_meta to df['subjectkey'] based on matching ID
guid_map = df_meta.set_index('ID')['GUID'].to_dict()
df['src_subject_id'] = df['src_subject_id'].astype(str).str.strip()
df['subjectkey'] = df['src_subject_id'].map(guid_map)
# Merge SEX from df_meta to df['sex'] based on matching ID
sex_map = df_meta.set_index('ID')['SEX'].to_dict()
df['sex'] = df['src_subject_id'].map(sex_map)
# Merge date_of_birth from df_meta into df
dob_map = df_meta.set_index('ID')['date_of_birth'].to_dict()
df['date_of_birth'] = df['src_subject_id'].map(dob_map)
df['interview_age'] = df.apply(
    lambda row: calculate_age_months(row['date_of_birth'], row['interview_date']), 
    axis=1
)
# Set dsm5crossad_24 to 1 as english
df['dsm5crossad_24'] = '1'
# Set PHQ9's missing value to -9
dsm_cols = [f'dsm5crossad_{i}' for i in range(1, 24)]
df[dsm_cols] = df[dsm_cols].fillna(-9)
# Convert interview_age to integer
df['interview_age'] = df['interview_age'].astype('Int64')
df[dsm_cols] = df[dsm_cols].astype('Int64')
df = df.astype(object)
df = df.where(pd.notnull(df), None)
df = df.dropna(subset=['interview_age', 'interview_date'])
# Convert interview_date to 'MM/DD/YYYY' string format
df['interview_date'] = pd.to_datetime(df['interview_date'])
df['interview_date'] = df['interview_date'].dt.strftime('%m/%d/%Y')
# Trim df to only have columns as in df_template, in the exact same order
df = df[df_template.columns.tolist()]
# Add the first row from template_path to df
df = pd.concat([first_row_template, df], ignore_index=True)
df.iloc[0] = df.iloc[0].fillna('')
df.iloc[:1].to_csv(results_file, index=False, header=False, mode='w')
df.iloc[1:].to_csv(results_file, index=False, header=True, mode='a')

# %%
#5. cde_whodas01
#NDA: 0=None; 1=Mild; 2=Moderate; 3=Severe; 4=Extreme or cannot do; -9 = Missing
#whodas_13: In what language did you collect the data? set to 1(English)
questionaire_name = 'cde_whodas01'
results_file = os.path.join(result_dir, f'{questionaire_name}.csv')
template_path = [f for f in glob.glob(os.path.join(approved_dir, '*.csv')) if questionaire_name.lower() in os.path.basename(f).lower()][0]
redcap_file_path = [f for f in glob.glob(os.path.join(redcap_file_dir, '*.csv')) if questionaire_name.lower() in os.path.basename(f).lower()][0]
df_template = pd.read_csv(template_path, header=1)
# Read the first row of template_path with all columns
first_row_template = pd.read_csv(template_path, header=None, nrows=1, names=df_template.columns)
df_redcap = pd.read_csv(redcap_file_path)
df_target_match_names = df_match_names.parse(questionaire_name, usecols=[0, 1])
valid_mappings = df_target_match_names.dropna(subset=['REDCap'])
df = df_template.copy() 
for index, row in valid_mappings.iterrows():
    nda_col = row['NDA_template']  # The destination column name
    redcap_col = row['REDCap']     # The source column name
    if redcap_col in df_redcap.columns:
        df[nda_col] = df_redcap[redcap_col]
# Merge GUID from df_meta to df['subjectkey'] based on matching ID
guid_map = df_meta.set_index('ID')['GUID'].to_dict()
df['src_subject_id'] = df['src_subject_id'].astype(str).str.strip()
df['subjectkey'] = df['src_subject_id'].map(guid_map)
# Merge SEX from df_meta to df['sex'] based on matching ID
sex_map = df_meta.set_index('ID')['SEX'].to_dict()
df['sex'] = df['src_subject_id'].map(sex_map)
# Merge date_of_birth from df_meta into df
dob_map = df_meta.set_index('ID')['date_of_birth'].to_dict()
df['date_of_birth'] = df['src_subject_id'].map(dob_map)
df['interview_age'] = df.apply(
    lambda row: calculate_age_months(row['date_of_birth'], row['interview_date']), 
    axis=1
)
# Set whodas_13 to 1 as english
df['whodas_13'] = '1'
# Set cde_whodas01's missing value to -9
dsm_cols = [f'whodas_{i}' for i in range(1, 13)]
df[dsm_cols] = df[dsm_cols].fillna(-9)
df[dsm_cols] = df[dsm_cols].astype('Int64')
# Convert interview_age to integer
df['interview_age'] = df['interview_age'].astype('Int64')
df = df.astype(object)
df = df.where(pd.notnull(df), None)
df = df.dropna(subset=['interview_age', 'interview_date'])
# Convert interview_date to 'MM/DD/YYYY' string format
df['interview_date'] = pd.to_datetime(df['interview_date'])
df['interview_date'] = df['interview_date'].dt.strftime('%m/%d/%Y')
# Trim df to only have columns as in df_template, in the exact same order
df = df[df_template.columns.tolist()]
# Add the first row from template_path to df
df = pd.concat([first_row_template, df], ignore_index=True)
df.iloc[0] = df.iloc[0].fillna('')
df.iloc[:1].to_csv(results_file, index=False, header=False, mode='w')
df.iloc[1:].to_csv(results_file, index=False, header=True, mode='a')

# %%
#1. SCID 
#scidv_rv01 for now
#scidv_mdd_lp: Major Depressive Disorders - Lifetime Prevalence; 0=Absent; 1=Present; -99 = Missing
#bodydysmorphiclp: Body Dysmorphic Lifetime Prevalence; 1 = absent; 2 = sub-threshold; 3 = threshold; -9 = no data
#scid_p88: Body Dysmorphic Disorder: Past Month; 1 = absent ; 3 = confirmed ; 555= Missing
#scid_sad_lifetime: Social Anxiety Disorder - Lifetime; 0 = Unknown/Inadequate Information; 1 = Absent; 2 = Sub-threshold; 3 = Threshold
#scid_gad_lifetime: Generalized Anxiety Disorder - Lifetime; 0 = Unknown/Inadequate Information; 1 = Absent; 2 = Sub-threshold; 3 = Threshold
questionaire_name = 'scidv_rv01'
results_file = os.path.join(result_dir, f'{questionaire_name}.csv')

# Find file paths
template_path = [f for f in glob.glob(os.path.join(approved_dir, '*.csv')) if questionaire_name.lower() in os.path.basename(f).lower()][0]
defination_path = [f for f in glob.glob(os.path.join(defination_dir, '*.csv')) if questionaire_name.lower() in os.path.basename(f).lower()][0]
redcap_file_path = [f for f in glob.glob(os.path.join(redcap_file_dir, '*.csv')) if questionaire_name.lower() in os.path.basename(f).lower()][0]

# Load DataFrames
df_template = pd.read_csv(template_path, header=1)
first_row_template = pd.read_csv(template_path, header=None, nrows=1, names=df_template.columns)
df_redcap = pd.read_csv(redcap_file_path)

# Load Mapping
df_target_match_names = df_match_names.parse(questionaire_name, usecols=[0, 1])
valid_mappings = df_target_match_names.dropna(subset=['REDCap'])

# Apply Mappings
df = df_template.copy() 
for index, row in valid_mappings.iterrows():
    nda_col = row['NDA_template'] 
    redcap_col = row['REDCap']     
    if redcap_col in df_redcap.columns:
        df[nda_col] = df_redcap[redcap_col]

# Merge GUID and Basic Info
guid_map = df_meta.set_index('ID')['GUID'].to_dict()
df['src_subject_id'] = df['src_subject_id'].astype(str).str.strip()
df['subjectkey'] = df['src_subject_id'].map(guid_map)

sex_map = df_meta.set_index('ID')['SEX'].to_dict()
df['sex'] = df['src_subject_id'].map(sex_map)

dob_map = df_meta.set_index('ID')['date_of_birth'].to_dict()
df['date_of_birth'] = df['src_subject_id'].map(dob_map)

df['interview_age'] = df.apply(
    lambda row: calculate_age_months(row['date_of_birth'], row['interview_date']), 
    axis=1
)
df['scidv_mdd_lp'] = df['scidv_mdd_lp'].map(dic_mdd_lp)

# --- Manual Fixes (Apply these BEFORE type enforcement) ---
# Set scidv_mdd_lp missing value to -99
df['scidv_mdd_lp'] = df['scidv_mdd_lp'].fillna(-99)
# Set bodydysmorphiclp missing value to -9
df['bodydysmorphiclp'] = df['bodydysmorphiclp'].fillna(-9)
# Set scid_p88 missing value to 555
df['scid_p88'] = df['scid_p88'].fillna(555)


# --- DYNAMIC TYPE ENFORCEMENT ---
# 1. Load the definition file
df_def = pd.read_csv(defination_path)
dtype_map = dict(zip(df_def['ElementName'], df_def['DataType']))

# 2. Iterate and apply types
for col in df.columns:
    if col in dtype_map:
        target_type = str(dtype_map[col])
        if 'Integer' in target_type:
            df[col] = pd.to_numeric(df[col], errors='coerce').astype('Int64')
        elif 'Float' in target_type:
            df[col] = pd.to_numeric(df[col], errors='coerce')

# Convert interview_age to integer
df['interview_age'] = df['interview_age'].astype('Int64')

# Drop rows missing critical info
df = df.dropna(subset=['interview_age', 'interview_date'])

# Format Date
df['interview_date'] = pd.to_datetime(df['interview_date'])
df['interview_date'] = df['interview_date'].dt.strftime('%m/%d/%Y')

# Trim columns to match template
df = df[df_template.columns.tolist()]

# --- CRITICAL FIX START ---
# Convert to object to allow mixing Strings (Header) and Integers (Data)
# This preserves the "Int64" formatting (no decimals) but allows the concat below to work.
df = df.astype(object)

# Replace 'pd.NA' (from Int64) with None/Empty string so CSV doesn't print '<NA>'
df = df.where(pd.notnull(df), '')
# --- CRITICAL FIX END ---

# Add the first row (headers) from template
df = pd.concat([first_row_template, df], ignore_index=True)

# Now this fillna will work because the column is type 'object', not 'Int64'
df.iloc[0] = df.iloc[0].fillna('')

# Write to CSV
df.iloc[:1].to_csv(results_file, index=False, header=False, mode='w')
df.iloc[1:].to_csv(results_file, index=False, header=True, mode='a')
# Out:
# /var/folders/63/3j_hstl96w58qx1sdw9czhxr0000gn/T/ipykernel_90171/4014138881.py:54: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['bodydysmorphiclp'] = df['bodydysmorphiclp'].fillna(-9)
# /var/folders/63/3j_hstl96w58qx1sdw9czhxr0000gn/T/ipykernel_90171/4014138881.py:56: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['scid_p88'] = df['scid_p88'].fillna(555)

# %%
#2. lsas01_sr
# #NDA: 
#fear 0::3;-7; -9	0=None; 1=Mild; 2=Moderate; 3=Severe; -7; -9=incomplete
#avoidence 0=Never; 1=Occasionally; 2=Often; 3=Usually; 4=Almost always; -7; -9=Incomplete
questionaire_name = 'lsas01_sr'
results_file = os.path.join(result_dir, f'{questionaire_name}.csv')
template_path = [f for f in glob.glob(os.path.join(approved_dir, '*.csv')) if questionaire_name.lower() in os.path.basename(f).lower()][0]
redcap_file_path = [f for f in glob.glob(os.path.join(redcap_file_dir, '*.csv')) if questionaire_name.lower() in os.path.basename(f).lower()][0]
df_template = pd.read_csv(template_path, header=1)
# Read the first row of template_path with all columns
first_row_template = pd.read_csv(template_path, header=None, nrows=1, names=df_template.columns)
df_redcap = pd.read_csv(redcap_file_path)
df_target_match_names = df_match_names.parse(questionaire_name, usecols=[0, 1])
valid_mappings = df_target_match_names.dropna(subset=['REDCap'])
df = df_template.copy() 
for index, row in valid_mappings.iterrows():
    nda_col = row['NDA_template']  # The destination column name
    redcap_col = row['REDCap']     # The source column name
    if redcap_col in df_redcap.columns:
        df[nda_col] = df_redcap[redcap_col]
# Merge GUID from df_meta to df['subjectkey'] based on matching ID
guid_map = df_meta.set_index('ID')['GUID'].to_dict()
df['src_subject_id'] = df['src_subject_id'].astype(str).str.strip()
df['subjectkey'] = df['src_subject_id'].map(guid_map)
# Merge SEX from df_meta to df['sex'] based on matching ID
sex_map = df_meta.set_index('ID')['SEX'].to_dict()
df['sex'] = df['src_subject_id'].map(sex_map)
# Merge date_of_birth from df_meta into df
dob_map = df_meta.set_index('ID')['date_of_birth'].to_dict()
df['date_of_birth'] = df['src_subject_id'].map(dob_map)
df['interview_age'] = df.apply(
    lambda row: calculate_age_months(row['date_of_birth'], row['interview_date']), 
    axis=1
)
# Convert interview_age to integer
df['interview_age'] = df['interview_age'].astype('Int64')
# Set lsps01_sr's missing value to -9
start_col = 'phonpubf'
end_col = 'resista'
fill_val = -9
cols_to_fix = df.loc[:, start_col:end_col].columns
df[cols_to_fix] = df[cols_to_fix].fillna(fill_val)
df[cols_to_fix] = df[cols_to_fix].astype('Int64')

df = df.astype(object)
df = df.where(pd.notnull(df), None)
df = df.dropna(subset=['interview_age', 'interview_date'])
# Convert interview_date to 'MM/DD/YYYY' string format
df['interview_date'] = pd.to_datetime(df['interview_date'])
df['interview_date'] = df['interview_date'].dt.strftime('%m/%d/%Y')
# Trim df to only have columns as in df_template, in the exact same order
df = df[df_template.columns.tolist()]
# Add the first row from template_path to df
df = pd.concat([first_row_template, df], ignore_index=True)
df.iloc[0] = df.iloc[0].fillna('')
df.iloc[:1].to_csv(results_file, index=False, header=False, mode='w')
df.iloc[1:].to_csv(results_file, index=False, header=True, mode='a')

# %%
#2. lsas01_sr
# #NDA: 
#fear 0::3;-7; -9	0=None; 1=Mild; 2=Moderate; 3=Severe; -7; -9=incomplete
#avoidence 0=Never; 1=Occasionally; 2=Often; 3=Usually; 4=Almost always; -7; -9=Incomplete
questionaire_name = 'lsas01_sr'
results_file = os.path.join(result_dir, f'{questionaire_name}.csv')
template_path = [f for f in glob.glob(os.path.join(approved_dir, '*.csv')) if questionaire_name.lower() in os.path.basename(f).lower()][0]
redcap_file_path = [f for f in glob.glob(os.path.join(redcap_file_dir, '*.csv')) if questionaire_name.lower() in os.path.basename(f).lower()][0]
df_template = pd.read_csv(template_path, header=1)
# Read the first row of template_path with all columns
first_row_template = pd.read_csv(template_path, header=None, nrows=1, names=df_template.columns)
df_redcap = pd.read_csv(redcap_file_path)
df_target_match_names = df_match_names.parse(questionaire_name, usecols=[0, 1])
valid_mappings = df_target_match_names.dropna(subset=['REDCap'])
df = df_template.copy() 
for index, row in valid_mappings.iterrows():
    nda_col = row['NDA_template']  # The destination column name
    redcap_col = row['REDCap']     # The source column name
    if redcap_col in df_redcap.columns:
        df[nda_col] = df_redcap[redcap_col]
# Merge GUID from df_meta to df['subjectkey'] based on matching ID
guid_map = df_meta.set_index('ID')['GUID'].to_dict()
df['src_subject_id'] = df['src_subject_id'].astype(str).str.strip()
df['subjectkey'] = df['src_subject_id'].map(guid_map)
# Merge SEX from df_meta to df['sex'] based on matching ID
sex_map = df_meta.set_index('ID')['SEX'].to_dict()
df['sex'] = df['src_subject_id'].map(sex_map)
# Merge date_of_birth from df_meta into df
dob_map = df_meta.set_index('ID')['date_of_birth'].to_dict()
df['date_of_birth'] = df['src_subject_id'].map(dob_map)
df['interview_age'] = df.apply(
    lambda row: calculate_age_months(row['date_of_birth'], row['interview_date']), 
    axis=1
)
# Convert interview_age to integer
df['interview_age'] = df['interview_age'].astype('Int64')
# Set lsps01_sr's missing value to -9
start_col = 'phonpubf'
end_col = 'resista'
fill_val = -9
cols_to_fix = df.loc[:, start_col:end_col].columns
df[cols_to_fix] = df[cols_to_fix].fillna(fill_val)
df[cols_to_fix] = df[cols_to_fix].astype('Int64')

df = df.astype(object)
df = df.where(pd.notnull(df), None)
df = df.dropna(subset=['interview_age', 'interview_date'])
# Convert interview_date to 'MM/DD/YYYY' string format
df['interview_date'] = pd.to_datetime(df['interview_date'])
df['interview_date'] = df['interview_date'].dt.strftime('%m/%d/%Y')
# Trim df to only have columns as in df_template, in the exact same order
df = df[df_template.columns.tolist()]
# Add the first row from template_path to df
df = pd.concat([first_row_template, df], ignore_index=True)
df.iloc[0] = df.iloc[0].fillna('')
df.iloc[:1].to_csv(results_file, index=False, header=False, mode='w')
df.iloc[1:].to_csv(results_file, index=False, header=True, mode='a')

# %%
#2. lsas01_cr
# #NDA: 
#fear 0::3;-7; -9	0=None; 1=Mild; 2=Moderate; 3=Severe; -7; -9=incomplete
#avoidence 0=Never; 1=Occasionally; 2=Often; 3=Usually; 4=Almost always; -7; -9=Incomplete
questionaire_name = 'lsas01_cr'
results_file = os.path.join(result_dir, f'{questionaire_name}.csv')
template_path = [f for f in glob.glob(os.path.join(approved_dir, '*.csv')) if questionaire_name.lower() in os.path.basename(f).lower()][0]
redcap_file_path = [f for f in glob.glob(os.path.join(redcap_file_dir, '*.csv')) if questionaire_name.lower() in os.path.basename(f).lower()][0]
df_template = pd.read_csv(template_path, header=1)
# Read the first row of template_path with all columns
first_row_template = pd.read_csv(template_path, header=None, nrows=1, names=df_template.columns)
df_redcap = pd.read_csv(redcap_file_path)
df_target_match_names = df_match_names.parse(questionaire_name, usecols=[0, 1])
valid_mappings = df_target_match_names.dropna(subset=['REDCap'])
df = df_template.copy() 
for index, row in valid_mappings.iterrows():
    nda_col = row['NDA_template']  # The destination column name
    redcap_col = row['REDCap']     # The source column name
    if redcap_col in df_redcap.columns:
        df[nda_col] = df_redcap[redcap_col]
# Merge GUID from df_meta to df['subjectkey'] based on matching ID
guid_map = df_meta.set_index('ID')['GUID'].to_dict()
df['src_subject_id'] = df['src_subject_id'].astype(str).str.strip()
df['subjectkey'] = df['src_subject_id'].map(guid_map)
# Merge SEX from df_meta to df['sex'] based on matching ID
sex_map = df_meta.set_index('ID')['SEX'].to_dict()
df['sex'] = df['src_subject_id'].map(sex_map)
# Merge date_of_birth from df_meta into df
dob_map = df_meta.set_index('ID')['date_of_birth'].to_dict()
df['date_of_birth'] = df['src_subject_id'].map(dob_map)
df['interview_age'] = df.apply(
    lambda row: calculate_age_months(row['date_of_birth'], row['interview_date']), 
    axis=1
)
# Convert interview_age to integer
df['interview_age'] = df['interview_age'].astype('Int64')
# Set lsps01_sr's missing value to -9
start_col = 'phonpubf'
end_col = 'resista'
fill_val = -9
cols_to_fix = df.loc[:, start_col:end_col].columns
df[cols_to_fix] = df[cols_to_fix].fillna(fill_val)
df[cols_to_fix] = df[cols_to_fix].astype('Int64')

df = df.astype(object)
df = df.where(pd.notnull(df), None)
df = df.dropna(subset=['interview_age', 'interview_date'])
# Convert interview_date to 'MM/DD/YYYY' string format
df['interview_date'] = pd.to_datetime(df['interview_date'])
df['interview_date'] = df['interview_date'].dt.strftime('%m/%d/%Y')
# Trim df to only have columns as in df_template, in the exact same order
df = df[df_template.columns.tolist()]
# Add the first row from template_path to df
df = pd.concat([first_row_template, df], ignore_index=True)
df.iloc[0] = df.iloc[0].fillna('')
df.iloc[:1].to_csv(results_file, index=False, header=False, mode='w')
df.iloc[1:].to_csv(results_file, index=False, header=True, mode='a')

# %%
#3. sds01
#NDA: 0=not at all; 1-3=mildly; 4-6=moderately; 7-9=markedly; 10=extremely; -7= I have not worked/studied at all during the past week for reasons unrelated to the disorder
questionaire_name = 'sds01'
results_file = os.path.join(result_dir, f'{questionaire_name}.csv')
template_path = [f for f in glob.glob(os.path.join(approved_dir, '*.csv')) if questionaire_name.lower() in os.path.basename(f).lower()][0]
redcap_file_path = [f for f in glob.glob(os.path.join(redcap_file_dir, '*.csv')) if questionaire_name.lower() in os.path.basename(f).lower()][0]
df_template = pd.read_csv(template_path, header=1)
# Read the first row of template_path with all columns
first_row_template = pd.read_csv(template_path, header=None, nrows=1, names=df_template.columns)
df_redcap = pd.read_csv(redcap_file_path)
df_target_match_names = df_match_names.parse(questionaire_name, usecols=[0, 1])
valid_mappings = df_target_match_names.dropna(subset=['REDCap'])
df = df_template.copy() 
for index, row in valid_mappings.iterrows():
    nda_col = row['NDA_template']  # The destination column name
    redcap_col = row['REDCap']     # The source column name
    if redcap_col in df_redcap.columns:
        df[nda_col] = df_redcap[redcap_col]
# Merge GUID from df_meta to df['subjectkey'] based on matching ID
guid_map = df_meta.set_index('ID')['GUID'].to_dict()
df['src_subject_id'] = df['src_subject_id'].astype(str).str.strip()
df['subjectkey'] = df['src_subject_id'].map(guid_map)
# Merge SEX from df_meta to df['sex'] based on matching ID
sex_map = df_meta.set_index('ID')['SEX'].to_dict()
df['sex'] = df['src_subject_id'].map(sex_map)
# Merge date_of_birth from df_meta into df
dob_map = df_meta.set_index('ID')['date_of_birth'].to_dict()
df['date_of_birth'] = df['src_subject_id'].map(dob_map)
df['interview_age'] = df.apply(
    lambda row: calculate_age_months(row['date_of_birth'], row['interview_date']), 
    axis=1
)
# Convert interview_age to integer
df['interview_age'] = df['interview_age'].astype('Int64')

df = df.astype(object)
df = df.where(pd.notnull(df), None)
df = df.dropna(subset=['interview_age', 'interview_date'])
# Convert interview_date to 'MM/DD/YYYY' string format
df['interview_date'] = pd.to_datetime(df['interview_date'])
df['interview_date'] = df['interview_date'].dt.strftime('%m/%d/%Y')
# Trim df to only have columns as in df_template, in the exact same order
df = df[df_template.columns.tolist()]
# Add the first row from template_path to df
df = pd.concat([first_row_template, df], ignore_index=True)
df.iloc[0] = df.iloc[0].fillna('')
df.iloc[:1].to_csv(results_file, index=False, header=False, mode='w')
df.iloc[1:].to_csv(results_file, index=False, header=True, mode='a')

# %%
#4. imaging

# %%
#5. qids01
#NDA: 0::3; 999=missing
questionaire_name = 'qids01'
results_file = os.path.join(result_dir, f'{questionaire_name}.csv')
template_path = [f for f in glob.glob(os.path.join(approved_dir, '*.csv')) if questionaire_name.lower() in os.path.basename(f).lower()][0]
redcap_file_path = [f for f in glob.glob(os.path.join(redcap_file_dir, '*.csv')) if questionaire_name.lower() in os.path.basename(f).lower()][0]
df_template = pd.read_csv(template_path, header=1)
# Read the first row of template_path with all columns
first_row_template = pd.read_csv(template_path, header=None, nrows=1, names=df_template.columns)
df_redcap = pd.read_csv(redcap_file_path)
df_target_match_names = df_match_names.parse(questionaire_name, usecols=[0, 1])
valid_mappings = df_target_match_names.dropna(subset=['REDCap'])
df = df_template.copy() 
for index, row in valid_mappings.iterrows():
    nda_col = row['NDA_template']  # The destination column name
    redcap_col = row['REDCap']     # The source column name
    if redcap_col in df_redcap.columns:
        df[nda_col] = df_redcap[redcap_col]
# Merge GUID from df_meta to df['subjectkey'] based on matching ID
guid_map = df_meta.set_index('ID')['GUID'].to_dict()
df['src_subject_id'] = df['src_subject_id'].astype(str).str.strip()
df['subjectkey'] = df['src_subject_id'].map(guid_map)
# Merge SEX from df_meta to df['sex'] based on matching ID
sex_map = df_meta.set_index('ID')['SEX'].to_dict()
df['sex'] = df['src_subject_id'].map(sex_map)
# Merge date_of_birth from df_meta into df
dob_map = df_meta.set_index('ID')['date_of_birth'].to_dict()
df['date_of_birth'] = df['src_subject_id'].map(dob_map)
df['interview_age'] = df.apply(
    lambda row: calculate_age_months(row['date_of_birth'], row['interview_date']), 
    axis=1
)
# Convert interview_age to integer
df['interview_age'] = df['interview_age'].astype('Int64')
# Set lsps01_sr's missing value to -9
start_col = 'vsoin'
end_col = 'vagit'
fill_val = 999
cols_to_fix = df.loc[:, start_col:end_col].columns
df[cols_to_fix] = df[cols_to_fix].fillna(fill_val)
df[cols_to_fix] = df[cols_to_fix].astype('Int64')
df['qvtot'] = df['qvtot'].astype('Int64')

df = df.astype(object)
df = df.where(pd.notnull(df), None)
df = df.dropna(subset=['interview_age', 'interview_date'])
# Convert interview_date to 'MM/DD/YYYY' string format
df['interview_date'] = pd.to_datetime(df['interview_date'])
df['interview_date'] = df['interview_date'].dt.strftime('%m/%d/%Y')
# Trim df to only have columns as in df_template, in the exact same order
df = df[df_template.columns.tolist()]
# Add the first row from template_path to df
df = pd.concat([first_row_template, df], ignore_index=True)
df.iloc[0] = df.iloc[0].fillna('')
df.iloc[:1].to_csv(results_file, index=False, header=False, mode='w')
df.iloc[1:].to_csv(results_file, index=False, header=True, mode='a')

# %%
#6. pswq01
#NDA: 5= Not at all typical of me; 1= Very typical of me
#pswq_total, 99
#110	treatment_session_arm_1f
questionaire_name = 'pswq01'
results_file = os.path.join(result_dir, f'{questionaire_name}.csv')
template_path = [f for f in glob.glob(os.path.join(approved_dir, '*.csv')) if questionaire_name.lower() in os.path.basename(f).lower()][0]
redcap_file_path = [f for f in glob.glob(os.path.join(redcap_file_dir, '*.csv')) if questionaire_name.lower() in os.path.basename(f).lower()][0]
df_template = pd.read_csv(template_path, header=1)
# Read the first row of template_path with all columns
first_row_template = pd.read_csv(template_path, header=None, nrows=1, names=df_template.columns)
df_redcap = pd.read_csv(redcap_file_path)
df_target_match_names = df_match_names.parse(questionaire_name, usecols=[0, 1])
valid_mappings = df_target_match_names.dropna(subset=['REDCap'])
df = df_template.copy() 
for index, row in valid_mappings.iterrows():
    nda_col = row['NDA_template']  # The destination column name
    redcap_col = row['REDCap']     # The source column name
    if redcap_col in df_redcap.columns:
        df[nda_col] = df_redcap[redcap_col]
# Merge GUID from df_meta to df['subjectkey'] based on matching ID
guid_map = df_meta.set_index('ID')['GUID'].to_dict()
df['src_subject_id'] = df['src_subject_id'].astype(str).str.strip()
df['subjectkey'] = df['src_subject_id'].map(guid_map)
# Merge SEX from df_meta to df['sex'] based on matching ID
sex_map = df_meta.set_index('ID')['SEX'].to_dict()
df['sex'] = df['src_subject_id'].map(sex_map)
# Merge date_of_birth from df_meta into df
dob_map = df_meta.set_index('ID')['date_of_birth'].to_dict()
df['date_of_birth'] = df['src_subject_id'].map(dob_map)
df['interview_age'] = df.apply(
    lambda row: calculate_age_months(row['date_of_birth'], row['interview_date']), 
    axis=1
)
# Convert interview_age to integer
df['interview_age'] = df['interview_age'].astype('Int64')
# Set lsps01_sr's missing value to -9
start_col = 'pswq1'
end_col = 'pswq_total'
fill_val = 99
cols_to_fix = df.loc[:, start_col:end_col].columns
df[end_col] = df[end_col].fillna(fill_val)
df[cols_to_fix] = df[cols_to_fix].astype('Int64')
df['pswq_total'] = df['pswq_total'].astype('float')

df = df.astype(object)
df = df.where(pd.notnull(df), None)
df = df.dropna(subset=['interview_age', 'interview_date'])
# Convert interview_date to 'MM/DD/YYYY' string format
df['interview_date'] = pd.to_datetime(df['interview_date'])
df['interview_date'] = df['interview_date'].dt.strftime('%m/%d/%Y')
# Trim df to only have columns as in df_template, in the exact same order
df = df[df_template.columns.tolist()]
# Add the first row from template_path to df
df = pd.concat([first_row_template, df], ignore_index=True)
df.iloc[0] = df.iloc[0].fillna('')
df.iloc[:1].to_csv(results_file, index=False, header=False, mode='w')
df.iloc[1:].to_csv(results_file, index=False, header=True, mode='a')

# %%
df.columns
# Out:
# Index(['subjectkey', 'src_subject_id', 'interview_date', 'interview_age',
#        'sex', 'pswq1', 'pswq2', 'pswq3', 'pswq4', 'pswq5', 'pswq6', 'pswq7',
#        'pswq8', 'pswq9', 'pswq10', 'pswq11', 'pswq12', 'pswq13', 'pswq14',
#        'pswq15', 'pswq16', 'pswq_total', 'fspgod', 'site', 'pswqc_child_1',
#        'pswqc_child_2', 'pswqc_child_3', 'pswqc_child_4', 'pswqc_child_5',
#        'pswqc_child_6', 'pswqc_child_7', 'pswqc_child_8', 'pswqc_child_9',
#        'pswqc_child_10', 'pswqc_child_11', 'pswqc_child_12', 'pswqc_child_13',
#        'pswqc_child_14', 'respondent', 'version_form', 'comments_misc', 'rt_',
#        'time_elapsed', 'ref_child_id', 'timepoint_label'],
#       dtype='object')

# %%
#7. hars01
#NDA: 0::4
questionaire_name = 'hars01'
results_file = os.path.join(result_dir, f'{questionaire_name}.csv')
template_path = [f for f in glob.glob(os.path.join(approved_dir, '*.csv')) if questionaire_name.lower() in os.path.basename(f).lower()][0]
redcap_file_path = [f for f in glob.glob(os.path.join(redcap_file_dir, '*.csv')) if questionaire_name.lower() in os.path.basename(f).lower()][0]
df_template = pd.read_csv(template_path, header=1)
# Read the first row of template_path with all columns
first_row_template = pd.read_csv(template_path, header=None, nrows=1, names=df_template.columns)
df_redcap = pd.read_csv(redcap_file_path)
df_target_match_names = df_match_names.parse(questionaire_name, usecols=[0, 1])
valid_mappings = df_target_match_names.dropna(subset=['REDCap'])
df = df_template.copy() 
for index, row in valid_mappings.iterrows():
    nda_col = row['NDA_template']  # The destination column name
    redcap_col = row['REDCap']     # The source column name
    if redcap_col in df_redcap.columns:
        df[nda_col] = df_redcap[redcap_col]
# Merge GUID from df_meta to df['subjectkey'] based on matching ID
guid_map = df_meta.set_index('ID')['GUID'].to_dict()
df['src_subject_id'] = df['src_subject_id'].astype(str).str.strip()
df['subjectkey'] = df['src_subject_id'].map(guid_map)
# Merge SEX from df_meta to df['sex'] based on matching ID
sex_map = df_meta.set_index('ID')['SEX'].to_dict()
df['sex'] = df['src_subject_id'].map(sex_map)
# Merge date_of_birth from df_meta into df
dob_map = df_meta.set_index('ID')['date_of_birth'].to_dict()
df['date_of_birth'] = df['src_subject_id'].map(dob_map)
df['interview_age'] = df.apply(
    lambda row: calculate_age_months(row['date_of_birth'], row['interview_date']), 
    axis=1
)
# Convert interview_age to integer
df['interview_age'] = df['interview_age'].astype('Int64')
start_col = 'ham_a_q1'
end_col = 'ham_a_q14'
cols_to_fix = df.loc[:, start_col:end_col].columns
df[cols_to_fix] = df[cols_to_fix].astype('Int64')


df = df.astype(object)
df = df.where(pd.notnull(df), None)
df = df.dropna(subset=['interview_age', 'interview_date'])
# Convert interview_date to 'MM/DD/YYYY' string format
df['interview_date'] = pd.to_datetime(df['interview_date'])
df['interview_date'] = df['interview_date'].dt.strftime('%m/%d/%Y')
# Trim df to only have columns as in df_template, in the exact same order
df = df[df_template.columns.tolist()]
# Add the first row from template_path to df
df = pd.concat([first_row_template, df], ignore_index=True)
df.iloc[0] = df.iloc[0].fillna('')
df.iloc[:1].to_csv(results_file, index=False, header=False, mode='w')
df.iloc[1:].to_csv(results_file, index=False, header=True, mode='a')

# %%
#8. babs01
#NDA: 0::4
#babs_total Sum of Questions 1 - 6
questionaire_name = 'babs01'
results_file = os.path.join(result_dir, f'{questionaire_name}.csv')
template_path = [f for f in glob.glob(os.path.join(approved_dir, '*.csv')) if questionaire_name.lower() in os.path.basename(f).lower()][0]
redcap_file_path = [f for f in glob.glob(os.path.join(redcap_file_dir, '*.csv')) if questionaire_name.lower() in os.path.basename(f).lower()][0]
df_template = pd.read_csv(template_path, header=1)
# Read the first row of template_path with all columns
first_row_template = pd.read_csv(template_path, header=None, nrows=1, names=df_template.columns)
df_redcap = pd.read_csv(redcap_file_path)
df_target_match_names = df_match_names.parse(questionaire_name, usecols=[0, 1])
valid_mappings = df_target_match_names.dropna(subset=['REDCap'])
df = df_template.copy() 
for index, row in valid_mappings.iterrows():
    nda_col = row['NDA_template']  # The destination column name
    redcap_col = row['REDCap']     # The source column name
    if redcap_col in df_redcap.columns:
        df[nda_col] = df_redcap[redcap_col]
# Merge GUID from df_meta to df['subjectkey'] based on matching ID
guid_map = df_meta.set_index('ID')['GUID'].to_dict()
df['src_subject_id'] = df['src_subject_id'].astype(str).str.strip()
df['subjectkey'] = df['src_subject_id'].map(guid_map)
# Merge SEX from df_meta to df['sex'] based on matching ID
sex_map = df_meta.set_index('ID')['SEX'].to_dict()
df['sex'] = df['src_subject_id'].map(sex_map)
# Merge date_of_birth from df_meta into df
dob_map = df_meta.set_index('ID')['date_of_birth'].to_dict()
df['date_of_birth'] = df['src_subject_id'].map(dob_map)
df['interview_age'] = df.apply(
    lambda row: calculate_age_months(row['date_of_birth'], row['interview_date']), 
    axis=1
)
# Convert interview_age to integer
df['interview_age'] = df['interview_age'].astype('Int64')
start_col = 'conviction'
end_col = 'babs_total'
df.loc[:, start_col:end_col] = df.loc[:, start_col:end_col].astype('Int64')
df = df.astype(object)
df = df.where(pd.notnull(df), None)
df = df.dropna(subset=['interview_age', 'interview_date'])
# Convert interview_date to 'MM/DD/YYYY' string format
df['interview_date'] = pd.to_datetime(df['interview_date'])
df['interview_date'] = df['interview_date'].dt.strftime('%m/%d/%Y')
# Trim df to only have columns as in df_template, in the exact same order
df = df[df_template.columns.tolist()]
# Add the first row from template_path to df
df = pd.concat([first_row_template, df], ignore_index=True)
df.iloc[0] = df.iloc[0].fillna('')
df.iloc[:1].to_csv(results_file, index=False, header=False, mode='w')
df.iloc[1:].to_csv(results_file, index=False, header=True, mode='a')
# Out:
# /var/folders/63/3j_hstl96w58qx1sdw9czhxr0000gn/T/ipykernel_90171/1458140600.py:38: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '<IntegerArray>
# [   4,    3,    3,    2,    2,    1,    3,    3,    3,    3,
#  ...
#  <NA>, <NA>, <NA>, <NA>, <NA>,    4,    3,    0,    2,    1]
# Length: 317, dtype: Int64' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[:, start_col:end_col] = df.loc[:, start_col:end_col].astype('Int64')
# /var/folders/63/3j_hstl96w58qx1sdw9czhxr0000gn/T/ipykernel_90171/1458140600.py:38: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '<IntegerArray>
# [   3,    3,    2,    1,    1,    1,    1,    1,    2,    2,
#  ...
#  <NA>, <NA>, <NA>, <NA>, <NA>,    3,    1,    0,    1,    1]
# Length: 317, dtype: Int64' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[:, start_col:end_col] = df.loc[:, start_col:end_col].astype('Int64')
# /var/folders/63/3j_hstl96w58qx1sdw9czhxr0000gn/T/ipykernel_90171/1458140600.py:38: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '<IntegerArray>
# [   4,    3,    3,    2,    2,    1,    1,    3,    3,    3,
#  ...
#  <NA>, <NA>, <NA>, <NA>, <NA>,    3,    1,    0,    1,    1]
# Length: 317, dtype: Int64' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[:, start_col:end_col] = df.loc[:, start_col:end_col].astype('Int64')
# /var/folders/63/3j_hstl96w58qx1sdw9czhxr0000gn/T/ipykernel_90171/1458140600.py:38: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '<IntegerArray>
# [   3,    4,    2,    2,    1,    2,    0,    0,    2,    2,
#  ...
#  <NA>, <NA>, <NA>, <NA>, <NA>,    4,    2,    0,    0,    1]
# Length: 317, dtype: Int64' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[:, start_col:end_col] = df.loc[:, start_col:end_col].astype('Int64')
# /var/folders/63/3j_hstl96w58qx1sdw9czhxr0000gn/T/ipykernel_90171/1458140600.py:38: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '<IntegerArray>
# [   4,    4,    4,    3,    1,    2,    1,    1,    3,    3,
#  ...
#  <NA>, <NA>, <NA>, <NA>, <NA>,    4,    4,    0,    1,    0]
# Length: 317, dtype: Int64' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[:, start_col:end_col] = df.loc[:, start_col:end_col].astype('Int64')
# /var/folders/63/3j_hstl96w58qx1sdw9czhxr0000gn/T/ipykernel_90171/1458140600.py:38: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '<IntegerArray>
# [   2,    2,    2,    1,    1,    1,    1,    1,    1,    1,
#  ...
#  <NA>, <NA>, <NA>, <NA>, <NA>,    0,    0,    0,    0,    0]
# Length: 317, dtype: Int64' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[:, start_col:end_col] = df.loc[:, start_col:end_col].astype('Int64')
# /var/folders/63/3j_hstl96w58qx1sdw9czhxr0000gn/T/ipykernel_90171/1458140600.py:38: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '<IntegerArray>
# [   1,    3,    1,    1,    1,    1,    2,    2,    3,    3,
#  ...
#  <NA>, <NA>, <NA>, <NA>, <NA>,    4,    0,    0,    0,    0]
# Length: 317, dtype: Int64' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[:, start_col:end_col] = df.loc[:, start_col:end_col].astype('Int64')
# /var/folders/63/3j_hstl96w58qx1sdw9czhxr0000gn/T/ipykernel_90171/1458140600.py:38: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '<IntegerArray>
# [  20,   19,   16,   11,    8,    8,    7,    9,   14,   14,
#  ...
#  <NA>, <NA>, <NA>, <NA>, <NA>,   18,   11,    0,    5,    4]
# Length: 317, dtype: Int64' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[:, start_col:end_col] = df.loc[:, start_col:end_col].astype('Int64')

# %%
#9. rumination01
#NDA: 1 = Almost never; 2 = Sometimes; 3 = Often; 4 = Almost always
questionaire_name = 'rumination01'
results_file = os.path.join(result_dir, f'{questionaire_name}.csv')
template_path = [f for f in glob.glob(os.path.join(approved_dir, '*.csv')) if questionaire_name.lower() in os.path.basename(f).lower()][0]
redcap_file_path = [f for f in glob.glob(os.path.join(redcap_file_dir, '*.csv')) if questionaire_name.lower() in os.path.basename(f).lower()][0]
df_template = pd.read_csv(template_path, header=1)
# Read the first row of template_path with all columns
first_row_template = pd.read_csv(template_path, header=None, nrows=1, names=df_template.columns)
df_redcap = pd.read_csv(redcap_file_path)
df_target_match_names = df_match_names.parse(questionaire_name, usecols=[0, 1])
valid_mappings = df_target_match_names.dropna(subset=['REDCap'])
df = df_template.copy() 
for index, row in valid_mappings.iterrows():
    nda_col = row['NDA_template']  # The destination column name
    redcap_col = row['REDCap']     # The source column name
    if redcap_col in df_redcap.columns:
        df[nda_col] = df_redcap[redcap_col]
# Merge GUID from df_meta to df['subjectkey'] based on matching ID
guid_map = df_meta.set_index('ID')['GUID'].to_dict()
df['src_subject_id'] = df['src_subject_id'].astype(str).str.strip()
df['subjectkey'] = df['src_subject_id'].map(guid_map)
# Merge SEX from df_meta to df['sex'] based on matching ID
sex_map = df_meta.set_index('ID')['SEX'].to_dict()
df['sex'] = df['src_subject_id'].map(sex_map)
# Merge date_of_birth from df_meta into df
dob_map = df_meta.set_index('ID')['date_of_birth'].to_dict()
df['date_of_birth'] = df['src_subject_id'].map(dob_map)
df['interview_age'] = df.apply(
    lambda row: calculate_age_months(row['date_of_birth'], row['interview_date']), 
    axis=1
)
# Convert interview_age to integer
df['interview_age'] = df['interview_age'].astype('Int64')
start_col = 'rumination01'
end_col = 'rumination_total'
cols_to_fix = df.loc[:, start_col:end_col].columns
df[cols_to_fix] = df[cols_to_fix].astype('Int64')

df = df.astype(object)
df = df.where(pd.notnull(df), None)
df = df.dropna(subset=['interview_age', 'interview_date'])
# Convert interview_date to 'MM/DD/YYYY' string format
df['interview_date'] = pd.to_datetime(df['interview_date'])
df['interview_date'] = df['interview_date'].dt.strftime('%m/%d/%Y')
# Trim df to only have columns as in df_template, in the exact same order
df = df[df_template.columns.tolist()]
# Add the first row from template_path to df
df = pd.concat([first_row_template, df], ignore_index=True)
df.iloc[0] = df.iloc[0].fillna('')
df.iloc[:1].to_csv(results_file, index=False, header=False, mode='w')
df.iloc[1:].to_csv(results_file, index=False, header=True, mode='a')

# %%
# #10. image03
questionaire_name = 'image03'
results_file = os.path.join(result_dir, f'{questionaire_name}.csv')
# --- File Loading ---
template_path = [f for f in glob.glob(os.path.join(approved_dir, '*.csv')) if questionaire_name.lower() in os.path.basename(f).lower()][0]
defination_path = [f for f in glob.glob(os.path.join(defination_dir, '*.csv')) if questionaire_name.lower() in os.path.basename(f).lower()][0]
df_def = pd.read_csv(defination_path)
dtype_map = dict(zip(df_def['ElementName'], df_def['DataType']))
redcap_file_path = [f for f in glob.glob(os.path.join(redcap_file_dir, '*.csv')) if questionaire_name.lower() in os.path.basename(f).lower()][0]
df_redcap_ori = pd.read_csv(redcap_file_path)
target_column = "mri_exit_date"
df_redcap = df_redcap_ori[df_redcap_ori[target_column].notna()]

extract_file = os.path.join(sumission_dir, 'NDA_image03_extracted.csv')
df_extract_ori = pd.read_csv(extract_file)
# ---------------------------------------------------------
# clean MRI data 1: NDA_image03_extracted.csv
# ---------------------------------------------------------
# sub-304_ses-baseline1 is sub-304_ses-repeatbaseline
# sub-132_ses-baseline is not usable, get rid of them; set sub-132_ses-baseline1 to sub-132_ses-baseline
# sub-141_ses-baseline is not usable, get rid of them; set sub-141_ses-baseline1 to sub-141_ses-baseline
# sub-326_ses-T12 is sub-325_ses-T12
# sub-326_ses-T121 is sub-326_ses-T12
# --- Configuration & Variables ---
# Define the column names as per your dataset
sub_col = "ID"
ses_col = "visit"
img_col = "image_file"
# Dropping rules: (ID, visit) pairs to remove
# records_to_drop = [
#     ("132", "baseline"),
#     ("141", "baseline"),
#     ("141", "repeatbaseline"),
#     ("141", "T6")
# ]
# Mapping rules for corrections: (current_ID, current_visit) -> (new_ID, new_visit)
# mapping_rules = {
#     ("304", "baseline1"): ("304", "repeatbaseline"),
#     ("132", "baseline1"): ("132", "baseline"),
#     ("141", "baseline1"): ("141", "baseline"),
#     ("326", "T12"):       ("325", "T12"),
#     ("326", "T121"):      ("326", "T12")
# }
# --- Data Processing ---
# 1. Standardize column types to string to ensure exact matching
df_extract_ori[sub_col] = df_extract_ori[sub_col].astype(str)
df_extract_ori[ses_col] = df_extract_ori[ses_col].astype(str)
# 2. Drop the unusable sessions first
# for sub_id, ses_id in records_to_drop:
#     df_extract_ori = df_extract_ori[~((df_extract_ori[sub_col] == sub_id) & (df_extract_ori[ses_col] == ses_id))]
# 3. Apply the corrections mapping
# def apply_corrections(row):
#     current_key = (row[sub_col], row[ses_col])
#     if current_key in mapping_rules:
#         new_sub, new_ses = mapping_rules[current_key]
#         # Dynamically update the image_file path if the string pattern matches
#         if img_col in row and pd.notna(row[img_col]):
#             path_str = str(row[img_col])
#             # Replace subject pattern if it changed
#             if row[sub_col] != new_sub:
#                 path_str = path_str.replace(f"sub-{row[sub_col]}", f"sub-{new_sub}")
#             # Replace session pattern if it changed
#             if row[ses_col] != new_ses:
#                 path_str = path_str.replace(f"ses-{row[ses_col]}", f"ses-{new_ses}")
#             row[img_col] = path_str
            
#         row[sub_col] = new_sub
#         row[ses_col] = new_ses
#     return row
# df_extract = df_extract_ori.apply(apply_corrections, axis=1).copy()
df_extract = df_extract_ori.copy()
# ---------------------------------------------------------
#  [AUDIT 1]Check: Are we missing IDs right from the start?
# ---------------------------------------------------------
df_redcap['record_id'] = df_redcap['record_id'].astype(str).str.strip()
df_extract['src_subject_id'] = df_extract['src_subject_id'].astype(str).str.strip()
redcap_ids = set(df_redcap['record_id'].unique())
extract_ids = set(df_extract['src_subject_id'].unique())
missing_in_extract = redcap_ids - extract_ids
if missing_in_extract:
    print(f"\n[AUDIT 1] {len(missing_in_extract)} IDs exist in REDCap but are NOT in your extracted file.")
    print(f"Sample missing: {list(missing_in_extract)[:5]}")
else:
    print("\n[AUDIT 1] All REDCap IDs are present in the extraction file.")
# ---------------------------------------------------------
df_template = pd.read_csv(template_path, header=1)
first_row_template = pd.read_csv(template_path, header=None, nrows=1, names=df_template.columns)
# Initial DataFrame Setup
df = df_template.copy() 
common_cols = df_template.columns.intersection(df_extract.columns)
# Preserve original index to look up 'ID' later
df = df_extract[common_cols].copy()
# Merge GUID from df_meta
guid_map = df_meta.set_index('ID')['GUID'].to_dict()
df['src_subject_id'] = df['src_subject_id'].astype(str).str.strip()
df['subjectkey'] = df['src_subject_id'].map(guid_map)
# ---------------------------------------------------------
# [AUDIT 2]Check for missing GUIDs (Report Unique SubID)
# ---------------------------------------------------------
missing_guids = df[df['subjectkey'].isna()]
if not missing_guids.empty:
    # Use indices to lookup the original 'ID' in df_extract
    affected_indices = missing_guids.index
    unique_missing_ids = df_extract.loc[affected_indices, 'ID'].unique() if 'ID' in df_extract.columns else ["ID_COL_MISSING"]
    
    print(f"\n[AUDIT 2] {len(missing_guids)} rows failed to map a GUID.")
    print(f"   -> Affects {len(unique_missing_ids)} Unique Subject IDs: {unique_missing_ids}")
# ---------------------------------------------------------
# 1. Ensure IDs are strings
df['src_subject_id'] = df['src_subject_id'].astype(str).str.strip()
df_redcap['record_id'] = df_redcap['record_id'].astype(str).str.strip()
# 2. Optimization: Group REDCap data by ID
redcap_grouped = df_redcap.groupby('record_id')

# Precise mapping relationship variable between df_extract['visit'] and df_redcap['redcap_event_name']
visit_to_event_map = {
    'baseline': ['baseline_1_arm_1', 'baseline_1_arm_2'],
    'repeatbaseline': ['repeat_baseline_arm_1', 'repeat_baseline_arm_2'],
    't6': ['treatment_session_arm_1f'],
    't12': ['treatment_session_arm_1l', 't12_arm_2'],
}

def get_mri_date(row):
    subject_id = row['src_subject_id']
    visit_val = row['visit']
    
    if pd.isna(visit_val):
        return row['interview_date']
        
    visit_clean = str(visit_val).strip().lower()
    
    # Check if the extracted visit value exists in our explicit mapping rule
    if visit_clean in visit_to_event_map:
        target_events = visit_to_event_map[visit_clean]
        
        if subject_id in redcap_grouped.groups:
            subj_data = redcap_grouped.get_group(subject_id)
            # Find rows matching the specified target REDCap events
            match = subj_data[
                subj_data['redcap_event_name']
                .fillna('')
                .str.strip()
                .str.lower()
                .isin(target_events)
            ]
            if not match.empty:
                return match.iloc[0]['mri_exit_date']
                
    return row['interview_date']

# 3. Apply logic
df['interview_date'] = df.apply(get_mri_date, axis=1)
# Merge SEX & DOB
sex_map = df_meta.set_index('ID')['SEX'].to_dict()
df['sex'] = df['src_subject_id'].map(sex_map)
dob_map = df_meta.set_index('ID')['date_of_birth'].to_dict()
df['date_of_birth'] = df['src_subject_id'].map(dob_map)
df['interview_age'] = df.apply(
    lambda row: calculate_age_months(row['date_of_birth'], row['interview_date']), 
    axis=1
)
df['interview_age'] = df['interview_age'].astype('Int64')
df['experiment_id'] = df['experiment_id'].astype('Int64')
df['image_extent4'] = df['image_extent4'].astype('Int64')
df = df.astype(object)
df = df.where(pd.notnull(df), None)
# ---------------------------------------------------------
# [AUDIT 3]'MR structural (T2)' (Report Unique SubID)
# ---------------------------------------------------------
# Identify rows to drop
drop_mask_t2 = df['scan_type'].astype(str).str.contains('MR structural (T2)', case=False, na=False, regex=False)
rows_t2 = df[drop_mask_t2]
if not rows_t2.empty:
    affected_indices = rows_t2.index
    unique_t2_ids = df_extract.loc[affected_indices, 'ID'].unique() if 'ID' in df_extract.columns else ["ID_COL_MISSING"]
    
    print(f"\n[AUDIT 3]  Filtering out {len(rows_t2)} rows containing 'MR structural (T2)'.")
    print(f"   -> Affects {len(unique_t2_ids)} Unique Subject IDs: {unique_t2_ids}")
# Actual Drop
df = df[~drop_mask_t2].copy()
# ---------------------------------------------------------
# [AUDIT 4]'localizer scan' (Report Unique SubID)
# ---------------------------------------------------------
# Identify rows to drop
drop_mask_localizer = df['scan_type'].astype(str).str.contains('localizer scan', case=False, na=False)
rows_localizer = df[drop_mask_localizer]
if not rows_localizer.empty:
    affected_indices = rows_localizer.index
    unique_loc_ids = df_extract.loc[affected_indices, 'ID'].unique() if 'ID' in df_extract.columns else ["ID_COL_MISSING"]
    
    print(f"\n[AUDIT 4] Filtering out {len(rows_localizer)} rows containing 'localizer scan'.")
    print(f"   -> Affects {len(unique_loc_ids)} Unique Subject IDs: {unique_loc_ids}")
# Actual Drop (Keep the inverse of the drop mask)
df = df[~drop_mask_localizer].copy()
# ---------------------------------------------------------
# [AUDIT 5]Missing Age/Date (Report Unique SubID)
# ---------------------------------------------------------
# Filter rows that satisfy the drop condition
rows_to_drop = df[df['interview_age'].isnull() | df['interview_date'].isnull()]
if not rows_to_drop.empty:
    affected_indices = rows_to_drop.index
    unique_dropped_ids = df_extract.loc[affected_indices, 'ID'].unique() if 'ID' in df_extract.columns else ["ID_COL_MISSING"]
    print(f"\n[AUDIT 5]  Dropping {len(rows_to_drop)} rows due to missing Age or Date.")
    print(f"   -> Affects {len(unique_dropped_ids)} Unique Subject IDs: {unique_dropped_ids}")
else:
    print("\n[AUDIT 5] No rows dropped due to missing Age/Date.")
# Actual Drop
df = df.dropna(subset=['interview_age', 'interview_date'])
# ---------------------------------------------------------
# Final Formatting
# ---------------------------------------------------------
df['interview_date'] = pd.to_datetime(df['interview_date'])
df['interview_date'] = df['interview_date'].dt.strftime('%m/%d/%Y')

#keep only image folders from last summission to now
import shutil
# Configuration
old_redcap_file_path = os.path.join(redcap_file_dir, 'image03_2026-01-15.csv')
df_old_redcap = pd.read_csv(old_redcap_file_path, header=1)
# Define your column key as a variable
file_col = "image_file"

# Helper function to extract just the bare filename (e.g., "img_001.nii")
def get_bare_filename(val):
    if pd.isna(val) or str(val).lower() == "nan":
        return "missing"
    return os.path.basename(str(val)).strip().lower()


# 1. Standardize the image_file column in both DataFrames to bare filenames
df_file_cleaned = df[file_col].apply(get_bare_filename)
old_files_set = set(df_old_redcap[file_col].apply(get_bare_filename))

# 2. Filter df by checking which rows do NOT have their filename in the old set
# This keeps only rows where the image file is NOT present in df_old_redcap
df_cleaned = df[~df_file_cleaned.isin(old_files_set)].copy()

df = df[df_template.columns.tolist()]
df = pd.concat([first_row_template, df], ignore_index=True)
df.iloc[0] = df.iloc[0].fillna('')

df.iloc[:1].to_csv(results_file, index=False, header=False, mode='w')
df.iloc[1:].to_csv(results_file, index=False, header=True, mode='a')

print(f"\n[DONE] Final file saved to: {results_file}")
# Out:
# /var/folders/63/3j_hstl96w58qx1sdw9czhxr0000gn/T/ipykernel_70373/715091187.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_redcap['record_id'] = df_redcap['record_id'].astype(str).str.strip()
# /var/folders/63/3j_hstl96w58qx1sdw9czhxr0000gn/T/ipykernel_70373/715091187.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_redcap['record_id'] = df_redcap['record_id'].astype(str).str.strip()
# [AUDIT 1] All REDCap IDs are present in the extraction file.
#
# [AUDIT 3]  Filtering out 1 rows containing 'MR structural (T2)'.
#    -> Affects 1 Unique Subject IDs: ['307']
#
# [AUDIT 5]  Dropping 27 rows due to missing Age or Date.
#    -> Affects 3 Unique Subject IDs: ['153' '158' '334']
#
# [DONE] Final file saved to: /Users/xiaoqianxiao/lab/R01/NDA/sumission_20260715/filled/image03.csv

# %%
# keep only the defaced T1w images
# Configuration
root_dir = os.path.join(sumission_dir, 'final/image')
target_subfolder = 'anat'
target_tag = 'desc-defaced_T1w'

# SET TO FALSE TO ACTUALLY DELETE
#dry_run = True
dry_run = False

print(f"--- STARTING CLEANUP (Dry Run: {dry_run}) ---")
print(f"Scanning: {root_dir}\n")

cleaned_folders = 0
deleted_files = 0

for dirpath, dirnames, filenames in os.walk(root_dir):
    # Only process directories named 'anat'
    if os.path.basename(dirpath) == target_subfolder:
        cleaned_folders += 1
        print(f"Checking folder: {dirpath}")
        
        # 1. Identify the "Master" files (the defaced NIfTIs)
        # We look for files containing 'desc-defaced_T1w' ending in .nii or .nii.gz
        defaced_niftis = [f for f in filenames if target_tag in f and (f.endswith('.nii') or f.endswith('.nii.gz'))]
        
        # 2. Build the Whitelist (Files we MUST keep)
        whitelist = set()
        
        for nifti in defaced_niftis:
            # Add the image itself to whitelist
            whitelist.add(nifti)
            
            # Derive the corresponding JSON name
            # Logic: Remove 'desc-defaced_' and switch extension to .json
            # e.g., sub-102_..._desc-defaced_T1w.nii.gz -> sub-102_..._T1w.json
            
            # Remove extension first
            if nifti.endswith('.nii.gz'):
                stem = nifti[:-7]
            else:
                stem = nifti[:-4]
            
            # Remove the 'desc-defaced_' tag to match the original JSON
            # We use replace() to handle cases where it might be in the middle
            json_stem = stem.replace('desc-defaced_', '') 
            json_filename = json_stem + '.json'
            
            # If this JSON actually exists, add it to whitelist
            if json_filename in filenames:
                whitelist.add(json_filename)
        
        # 3. Delete everything NOT in the whitelist
        for file in filenames:
            if file not in whitelist:
                full_path = os.path.join(dirpath, file)
                
                if dry_run:
                    print(f"  [WOULD DELETE]: {file}")
                else:
                    os.remove(full_path)
                    print(f"  [DELETED]: {file}")
                deleted_files += 1
            else:
                # Optional: print what we are keeping just to be sure
                # print(f"  [KEEPING]: {file}")
                pass

print(f"\n--- SUMMARY ---")
print(f"Anat folders processed: {cleaned_folders}")
print(f"Files {'marked for deletion' if dry_run else 'deleted'}: {deleted_files}")

if dry_run and deleted_files > 0:
    print(">>> Logic look good? Set 'dry_run = False' and run again.")
# Out:
# --- STARTING CLEANUP (Dry Run: False) ---
# Scanning: /Users/xiaoqianxiao/lab/R01/NDA/sumission_20260715/final/image
#
# Checking folder: /Users/xiaoqianxiao/lab/R01/NDA/sumission_20260715/final/image/sub-302/ses-T12/anat
#   [DELETED]: sub-302_ses-T12_acq-MEMPRvNav_echo-3_T1w.nii.gz
#   [DELETED]: sub-302_ses-T12_acq-MEMPRvNav_echo-4_T1w.nii.gz
#   [DELETED]: sub-302_ses-T12_acq-MEMPRvNav_echo-1_T1w.nii.gz
#   [DELETED]: sub-302_ses-T12_acq-MEMPRvNav_echo-2_T1w.nii.gz
#   [DELETED]: sub-302_ses-T12_acq-MEMPRvNav_T1w.nii.gz
# Checking folder: /Users/xiaoqianxiao/lab/R01/NDA/sumission_20260715/final/image/sub-302/ses-repeatbaseline/anat
# Checking folder: /Users/xiaoqianxiao/lab/R01/NDA/sumission_20260715/final/image/sub-302/ses-baseline/anat
#   [DELETED]: sub-302_ses-baseline_acq-MEMPRvNav_echo-2_T1w.nii.gz
#   [DELETED]: sub-302_ses-baseline_acq-MEMPRvNav_echo-3_T1w.nii.gz
#   [DELETED]: sub-302_ses-baseline_acq-MEMPRvNav_echo-4_T1w.nii.gz
#   [DELETED]: sub-302_ses-baseline_acq-MEMPRvNav_T1w.nii.gz
#   [DELETED]: sub-302_ses-baseline_acq-MEMPRvNav_echo-1_T1w.nii.gz
# Checking folder: /Users/xiaoqianxiao/lab/R01/NDA/sumission_20260715/final/image/sub-130/ses-T12/anat
#   [DELETED]: sub-130_ses-T12_acq-MEMPRvNav_echo-2_T1w.nii.gz
#   [DELETED]: sub-130_ses-T12_acq-MEMPRvNav_echo-4_T1w.nii.gz
#   [DELETED]: sub-130_ses-T12_acq-MEMPRvNav_echo-1_T1w.nii.gz
#   [DELETED]: sub-130_ses-T12_acq-MEMPRvNav_T1w.nii.gz
#   [DELETED]: sub-130_ses-T12_acq-MEMPRvNav_echo-3_T1w.nii.gz
# Checking folder: /Users/xiaoqianxiao/lab/R01/NDA/sumission_20260715/final/image/sub-130/ses-T6/anat
#   [DELETED]: sub-130_ses-T6_acq-MEMPRvNav_echo-4_T1w.nii.gz
#   [DELETED]: sub-130_ses-T6_acq-MEMPRvNav_echo-1_T1w.nii.gz
#   [DELETED]: sub-130_ses-T6_acq-MEMPRvNav_echo-3_T1w.nii.gz
#   [DELETED]: sub-130_ses-T6_acq-MEMPRvNav_T1w.nii.gz
#   [DELETED]: sub-130_ses-T6_acq-MEMPRvNav_echo-2_T1w.nii.gz
# Checking folder: /Users/xiaoqianxiao/lab/R01/NDA/sumission_20260715/final/image/sub-130/ses-repeatbaseline/anat
#   [DELETED]: sub-130_ses-repeatbaseline_acq-MEMPRvNav_T1w.nii.gz
#   [DELETED]: sub-130_ses-repeatbaseline_acq-MEMPRvNav_echo-2_T1w.nii.gz
#   [DELETED]: sub-130_ses-repeatbaseline_acq-MEMPRvNav_echo-3_T1w.nii.gz
#   [DELETED]: sub-130_ses-repeatbaseline_acq-MEMPRvNav_echo-1_T1w.nii.gz
#   [DELETED]: sub-130_ses-repeatbaseline_acq-MEMPRvNav_echo-4_T1w.nii.gz
# Checking folder: /Users/xiaoqianxiao/lab/R01/NDA/sumission_20260715/final/image/sub-130/ses-baseline/anat
#   [DELETED]: sub-130_ses-baseline_acq-MEMPRvNav_echo-2_T1w.nii.gz
#   [DELETED]: sub-130_ses-baseline_acq-MEMPRvNav_echo-1_T1w.nii.gz
#   [DELETED]: sub-130_ses-baseline_acq-MEMPRvNav_echo-4_T1w.nii.gz
#   [DELETED]: sub-130_ses-baseline_acq-MEMPRvNav_T1w.nii.gz
#   [DELETED]: sub-130_ses-baseline_acq-MEMPRvNav_echo-3_T1w.nii.gz
# Checking folder: /Users/xiaoqianxiao/lab/R01/NDA/sumission_20260715/final/image/sub-137/ses-repeatbaseline/anat
#   [DELETED]: sub-137_ses-repeatbaseline_acq-MEMPRvNav_echo-2_T1w.nii.gz
#   [DELETED]: sub-137_ses-repeatbaseline_acq-MEMPRvNav_echo-4_T1w.nii.gz
#   [DELETED]: sub-137_ses-repeatbaseline_acq-MEMPRvNav_echo-1_T1w.nii.gz
#   [DELETED]: sub-137_ses-repeatbaseline_acq-MEMPRvNav_T1w.nii.gz
#   [DELETED]: sub-137_ses-repeatbaseline_acq-MEMPRvNav_echo-3_T1w.nii.gz
# Checking folder: /Users/xiaoqianxiao/lab/R01/NDA/sumission_20260715/final/image/sub-137/ses-baseline/anat
#   [DELETED]: sub-137_ses-baseline_acq-MEMPRvNav_echo-2_T1w.nii.gz
#   [DELETED]: sub-137_ses-baseline_acq-MEMPRvNav_echo-3_T1w.nii.gz
#   [DELETED]: sub-137_ses-baseline_acq-MEMPRvNav_T1w.nii.gz
#   [DELETED]: sub-137_ses-baseline_acq-MEMPRvNav_echo-1_T1w.nii.gz
#   [DELETED]: sub-137_ses-baseline_acq-MEMPRvNav_echo-4_T1w.nii.gz
# Checking folder: /Users/xiaoqianxiao/lab/R01/NDA/sumission_20260715/final/image/sub-305/ses-T12/anat
#   [DELETED]: sub-305_ses-T12_acq-MEMPRvNav_echo-4_T1w.nii.gz
#   [DELETED]: sub-305_ses-T12_acq-MEMPRvNav_echo-1_T1w.nii.gz
#   [DELETED]: sub-305_ses-T12_acq-MEMPRvNav_echo-3_T1w.nii.gz
#   [DELETED]: sub-305_ses-T12_acq-MEMPRvNav_T1w.nii.gz
#   [DELETED]: sub-305_ses-T12_acq-MEMPRvNav_echo-2_T1w.nii.gz
# Checking folder: /Users/xiaoqianxiao/lab/R01/NDA/sumission_20260715/final/image/sub-305/ses-repeatbaseline/anat
# Checking folder: /Users/xiaoqianxiao/lab/R01/NDA/sumission_20260715/final/image/sub-305/ses-baseline/anat
#   [DELETED]: sub-305_ses-baseline_acq-MEMPRvNav_echo-2_T1w.nii.gz
#   [DELETED]: sub-305_ses-baseline_acq-MEMPRvNav_echo-4_T1w.nii.gz
#   [DELETED]: sub-305_ses-baseline_acq-MEMPRvNav_echo-1_T1w.nii.gz
#   [DELETED]: sub-305_ses-baseline_acq-MEMPRvNav_T1w.nii.gz
#   [DELETED]: sub-305_ses-baseline_acq-MEMPRvNav_echo-3_T1w.nii.gz
# Checking folder: /Users/xiaoqianxiao/lab/R01/NDA/sumission_20260715/final/image/sub-108/ses-T12/anat
#   [DELETED]: sub-108_ses-T12_acq-MEMPRvNav_echo-2_T1w.nii.gz
#   [DELETED]: sub-108_ses-T12_acq-MEMPRvNav_echo-1_T1w.nii.gz
#   [DELETED]: sub-108_ses-T12_acq-MEMPRvNav_T1w.nii.gz
#   [DELETED]: sub-108_ses-T12_acq-MEMPRvNav_echo-4_T1w.nii.gz
#   [DELETED]: sub-108_ses-T12_acq-MEMPRvNav_echo-3_T1w.nii.gz
# Checking folder: /Users/xiaoqianxiao/lab/R01/NDA/sumission_20260715/final/image/sub-108/ses-T6/anat
# Checking folder: /Users/xiaoqianxiao/lab/R01/NDA/sumission_20260715/final/image/sub-108/ses-repeatbaseline/anat
# Checking folder: /Users/xiaoqianxiao/lab/R01/NDA/sumission_20260715/final/image/sub-108/ses-baseline/anat
#   [DELETED]: sub-108_ses-baseline_acq-MEMPRvNav_echo-2_T1w.nii.gz
#   [DELETED]: sub-108_ses-baseline_acq-MEMPRvNav_T1w.nii.gz
#   [DELETED]: sub-108_ses-baseline_acq-MEMPRvNav_echo-3_T1w.nii.gz
#   [DELETED]: sub-108_ses-baseline_acq-MEMPRvNav_echo-1_T1w.nii.gz
#   [DELETED]: sub-108_ses-baseline_acq-MEMPRvNav_echo-4_T1w.nii.gz
# Checking folder: /Users/xiaoqianxiao/lab/R01/NDA/sumission_20260715/final/image/sub
/Users/xiaoqianxiao/lab/R01/NDA/sumission_20260715/final/image/sub-2001LH/ses-pilotTR1000/anat
#
# --- SUMMARY ---
# Anat folders processed: 232
# Files deleted: 2435

# %%
# Print results
print(f"Original rows: {len(df)}")
print(f"Cleaned rows: {len(df_cleaned)}")
print(f"Rows dropped: {len(df) - len(df_cleaned)}")
# Out:
# Original rows: 1909
# Cleaned rows: 1305
# Rows dropped: 604

# %%
df_cleaned.shape
filtered_df = df_cleaned.copy()
filtered_df = filtered_df[df_template.columns.tolist()]
filtered_df = pd.concat([first_row_template, filtered_df], ignore_index=True)
filtered_df.iloc[0] = filtered_df.iloc[0].fillna('')
results_file_filtered = os.path.join(result_dir, f'{questionaire_name}_20260715.csv')
filtered_df.iloc[:1].to_csv(results_file_filtered, index=False, header=False, mode='w')
filtered_df.iloc[1:].to_csv(results_file_filtered, index=False, header=True, mode='a')

# %%
import os
import shutil

# Configuration
move_to_folder = '/Users/xiaoqianxiao/lab/R01/NDA/sumission_20260715/final/image_20260115'
old_redcap_file_path = os.path.join(redcap_file_dir, 'image03_2026-01-15.csv')
root_dir = '/Users/xiaoqianxiao/lab/R01/NDA/sumission_20260715/final/image'

# SET TO FALSE TO ACTUALLY MOVE FOLDERS
#dry_run = True
dry_run = False

print(f"--- STARTING DIRECTORY CLEANUP & RELOCATION (Dry Run: {dry_run}) ---")
print(f"Scanning: {root_dir}")
print(f"Moving invalid sessions to: {move_to_folder}\n")

# Ensure the destination base folder exists if we are not in dry run
if not dry_run:
    os.makedirs(move_to_folder, exist_ok=True)

# Create a lookup set of valid (subID, sesID) tuples for fast checking
valid_combinations = set(
    zip(
        filtered_df['src_subject_id'].astype(str), 
        filtered_df['visit'].astype(str)
    )
)

moved_folders = 0
kept_folders = 0

# Iterate through subject folders (e.g., sub-XXXX)
if os.path.exists(root_dir):
    for sub_dir in os.listdir(root_dir):
        sub_path = os.path.join(root_dir, sub_dir)
        
        # Ensure it's a directory and matches the 'sub-' prefix pattern
        if os.path.isdir(sub_path) and sub_dir.startswith('sub-'):
            sub_id = sub_dir.replace('sub-', '')
            
            # Track if this subject directory retains any valid sessions
            has_valid_sessions = False
            
            # Iterate through session folders (e.g., ses-XXXX) inside the subject folder
            for ses_dir in os.listdir(sub_path):
                ses_path = os.path.join(sub_path, ses_dir)
                
                if os.path.isdir(ses_path) and ses_dir.startswith('ses-'):
                    ses_id = ses_dir.replace('ses-', '')
                    
                    # Check if this specific subID and sesID pair exists in your filtered DataFrame
                    if (sub_id, ses_id) in valid_combinations:
                        print(f"  [KEEPING]: sub-{sub_id}/ses-{ses_id}")
                        kept_folders += 1
                        has_valid_sessions = True
                    else:
                        # Define target destination path maintaining sub/ses hierarchy
                        target_sub_dir = os.path.join(move_to_folder, sub_dir)
                        target_ses_path = os.path.join(target_sub_dir, ses_dir)
                        
                        if dry_run:
                            print(f"  [WOULD MOVE]: sub-{sub_id}/ses-{ses_id} -> {target_ses_path}")
                        else:
                            # Create the specific sub-XXXX directory in the destination if it doesn't exist
                            os.makedirs(target_sub_dir, exist_ok=True)
                            shutil.move(ses_path, target_ses_path)
                            print(f"  [MOVED]: sub-{sub_id}/ses-{ses_id} -> {target_ses_path}")
                        
                        moved_folders += 1
            
            # Clean up the original parent sub- folder if all its sessions were moved
            if not has_valid_sessions and os.path.exists(sub_path) and not os.listdir(sub_path):
                if dry_run:
                    print(f"  [WOULD REMOVE EMPTY ORIGINAL PARENT]: {sub_dir}")
                else:
                    os.rmdir(sub_path)
                    print(f"  [REMOVED EMPTY ORIGINAL PARENT]: {sub_dir}")

print(f"\n--- SUMMARY ---")
print(f"Folders kept: {kept_folders}")
print(f"Folders {'marked for moving' if dry_run else 'moved'}: {moved_folders}")

if dry_run and moved_folders > 0:
    print("\n>>> Logic looks good? Set 'dry_run = False' to execute the move.")
# Out:
# --- STARTING DIRECTORY CLEANUP & RELOCATION (Dry Run: False) ---
# Scanning: /Users/xiaoqianxiao/lab/R01/NDA/sumission_20260715/final/image
# Moving invalid sessions to: /Users/xiaoqianxiao/lab/R01/NDA/sumission_20260715/final/image_20260115
#
#   [MOVED]: sub-302/ses-T12 -> /Users/xiaoqianxiao/lab/R01/NDA/sumission_20260715/final/image_20260115/sub-302/ses-T12
#   [KEEPING]: sub-302/ses-repeatbaseline
#   [MOVED]: sub-302/ses-baseline -> /Users/xiaoqianxiao/lab/R01/NDA/sumission_20260715/final/image_20260115/sub-302/ses-baseline
#   [KEEPING]: sub-130/ses-T12
#   [KEEPING]: sub-130/ses-T6
#   [KEEPING]: sub-130/ses-repeatbaseline
#   [MOVED]: sub-130/ses-baseline -> /Users/xiaoqianxiao/lab/R01/NDA/sumission_20260715/final/image_20260115/sub-130/ses-baseline
#   [KEEPING]: sub-137/ses-repeatbaseline
#   [KEEPING]: sub-137/ses-baseline
#   [MOVED]: sub-305/ses-T12 -> /Users/xiaoqianxiao/lab/R01/NDA/sumission_20260715/final/image_20260115/sub-305/ses-T12
#   [KEEPING]: sub-305/ses-repeatbaseline
#   [MOVED]: sub-305/ses-baseline -> /Users/xiaoqianxiao/lab/R01/NDA/sumission_20260715/final/image_20260115/sub-305/ses-baseline
#   [KEEPING]: sub-108/ses-T12
#   [KEEPING]: sub-108/ses-T6
#   [KEEPING]: sub-108/ses-repeatbaseline
#   [MOVED]: sub-108/ses-baseline -> /Users/xiaoqianxiao/lab/R01/NDA/sumission_20260715/final/image_20260115/sub-108/ses-baseline
#   [KEEPING]: sub-333/ses-repeatbaseline
#   [KEEPING]: sub-333/ses-baseline
#   [MOVED]: sub-334/ses-T12 -> /Users/xiaoqianxiao/lab/R01/NDA/sumission_20260715/final/image_20260115/sub-334/ses-T12
#   [KEEPING]: sub-334/ses-baseline
#   [KEEPING]: sub-106/ses-T12
#   [KEEPING]: sub-106/ses-T6
#   [KEEPING]: sub-106/ses-repeatbaseline
#   [MOVED]: sub-106/ses-baseline -> /Users/xiaoqianxiao/lab/R01/NDA/sumission_20260715/final/image_20260115/sub-106/ses-baseline
#   [KEEPING]: sub-139/ses-T12
#   [KEEPING]: sub-139/ses-T6
#   [KEEPING]: sub-139/ses-repeatbaseline
#   [KEEPING]: sub-139/ses-baseline
#   [KEEPING]: sub-155/ses-repeatbaseline
#   [KEEPING]: sub-155/ses-baseline
#   [KEEPING]: sub-335/ses-T12
#   [KEEPING]: sub-335/ses-repeatbaseline
#   [KEEPING]: sub-335/ses-baseline
#   [KEEPING]: sub-138/ses-T12
#   [KEEPING]: sub-138/ses-T6
#   [KEEPING]: sub-138/ses-repeatbaseline
#   [KEEPING]: sub-138/ses-baseline
#   [KEEPING]: sub-332/ses-T12
#   [KEEPING]: sub-332/ses-repeatbaseline
#   [KEEPING]: sub-332/ses-baseline
#   [MOVED]: sub-304/ses-T12 -> /Users/xiaoqianxiao/lab/R01/NDA/sumission_20260715/final/image_20260115/sub-304/ses-T12
#   [KEEPING]: sub-304/ses-repeatbaseline
#   [MOVED]: sub-304/ses-baseline -> /Users/xiaoqianxiao/lab/R01/NDA/sumission_20260715/final/image_20260115/sub-304/ses-baseline
#   [KEEPING]: sub-136/ses-T12
#   [KEEPING]: sub-136/ses-T6
#   [KEEPING]: sub-136/ses-repeatbaseline
#   [MOVED]: sub-136/ses-baseline -> /Users/xiaoqianxiao/lab/R01/NDA/sumission_20260715/final/image_20260115/sub-136/ses-baseline
#   [MOVED]: sub-131/ses-baseline -> /Users/xiaoqianxiao/lab/R01/NDA/sumission_20260715/final/image_20260115/sub-131/ses-baseline
#   [REMOVED EMPTY ORIGINAL PARENT]: sub-131
#   [MOVED]: sub-303/ses-T12 -> /Users/xiaoqianxiao/lab/R01/NDA/sumission_20260715/final/image_20260115/sub-303/ses-T12
#   [KEEPING]: sub-303/ses-repeatbaseline
#   [MOVED]: sub-303/ses-baseline -> /Users/xiaoqianxiao/lab/R01/NDA/sumission_20260715/final/image_20260115/sub